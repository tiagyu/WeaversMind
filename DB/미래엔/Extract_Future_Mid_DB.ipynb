# %% [markdown]
# # 중등 미래엔 커리큘럼 작업

# %%
import pandas as pd
df = pd.read_csv("Future_Mid_DB.csv")
df.head()
# Out:
#    학년    출판사  교육과정  Lesson                    Title  \
# 0  중1  능률(김)  2015       1      Welcome to My World
# 1  중1  능률(김)  2015       2    Discover Your Culture
# 2  중1  능률(김)  2015       3  Spend Smart, Save Smart
# 3  중1  능률(김)  2015       4       The Power of Ideas
# 4  중1  능률(김)  2015       5       Follow Your Dreams
#
#                                   Functions (의사소통기능)  \
# 0  소개하고 답하기\nA: My name is Mina. I'm from Korea.\...
# 1  계획 묻고 답하기\nA: What are you going to do on your...
# 2  조언하기\nA: You should keep a spending diary.\nB:...
# 3  동의하기·이의 제기하기\nA: This movie is boring.\nB: I t...
# 4                  소망 말하기\nI want to be a scientist.
#
#                                 Functions (의사소통기능).1  \
# 0  좋아하는 것 묻고 답하기\nA: What is your favorite subjec...
# 1  장소 설명하기\nThere are many wonderful places in Ko...
# 2  허락 요청하고 답하기\nA: Can I try on this shirt?\nB: Y...
# 3  이유 묻고 답하기\nA: Why do you use this computer?\nB...
# 4                 격려하기\nDon't worry. You'll do fine.
#
# ...
